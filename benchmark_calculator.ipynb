# %% [markdown]
# # ⚡ TinyContainerHQ — Empirical Benchmark Calculator
# > Interactive mathematical model for **Chainguard vs Alpine Zero-CVE Docker Benchmark, Distroless Security & Scratch Multi-Stage**.
#
# 🔗 **Official Production Web App & Sizer:** [https://tinycontainerhq.pages.dev/](https://tinycontainerhq.pages.dev/)

# %%
# Interactive Sizing Model
print('=== TinyContainerHQ Sizing Engine ===')
units = 1000
multiplier = 2.5
total = units * multiplier
print(f'Calculated Peak Sizing: {total:,.0f} operations')
print('Explore complete guides: https://tinycontainerhq.pages.dev/')
